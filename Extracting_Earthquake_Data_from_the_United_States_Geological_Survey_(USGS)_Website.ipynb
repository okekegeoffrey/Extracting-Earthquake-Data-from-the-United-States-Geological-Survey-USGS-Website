# %% [markdown]
# <a href="https://colab.research.google.com/github/okekegeoffrey/Extracting-Earthquake-Data-from-the-United-States-Geological-Survey-USGS-Website/blob/main/Extracting_Earthquake_Data_from_the_United_States_Geological_Survey_(USGS)_Website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this project, you are expected to use Python to access the United States Geological Survey free API and download real-time earthquake events. This is a great exercise for learning how to use Python to send requests to a REST API and get data in return.
#
# The API endpoint to get earthquake data is as variable "api" below.

# %%
# import the necessary modules
import pandas as pd
import requests

# %%
# the link to the json API
api = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson"

# %%
# import the json into pandas
response = requests.get(api) # fetch the data
data = response.json() # parse the result as  json

# normalise the 'features' list to handle potential inconsistencies
df = pd.json_normalize(data['features'])

df.head(10)
# Out:
#       type            id  properties.mag  \
# 0  Feature    hv74388076            3.63
# 1  Feature    hv74388066            1.83
# 2  Feature    hv74388061            2.02
# 3  Feature  ak024a2i26z5            1.60
# 4  Feature    nc75044392            1.28
# 5  Feature    hv74388056            2.76
# 6  Feature    ci40864600            2.25
# 7  Feature    ci40864592            1.55
# 8  Feature  ak024a2hkfzf            1.00
# 9  Feature    pr71457023            3.42
#
#                                     properties.place  properties.time  \
# 0                          7 km S of Volcano, Hawaii    1722972316140
# 1                          7 km S of Volcano, Hawaii    1722972042720
# 2                        5 km SSW of Volcano, Hawaii    1722971632410
# 3                  15 km W of Four Mile Road, Alaska    1722971351531
# 4                  7 km SSW of San Juan Bautista, CA    1722971093970
# 5                          0 km NW of Pāhala, Hawaii    1722970898220
# 6                            7 km NNE of Fontana, CA    1722970462180
# 7                      16 km NNE of Apple Valley, CA    1722969858470
# 8                        15 km SSW of Badger, Alaska    1722968790191
# 9  77 km W of The Bottom, Bonaire, Saint Eustatiu...    1722968336740
#
#    properties.updated properties.tz  \
# 0       1722973092040          None
# 1       1722972200030          None
# 2       1722971791330          None
# 3       1722971465922          None
# 4       1722971189115          None
# 5       1722971075620          None
# 6       1722971909795          None
# 7       1722970755563          None
# 8       1722968902703          None
# 9       1722971153040          None
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
# 5  https://earthquake.usgs.gov/earthquakes/eventp...
# 6  https://earthquake.usgs.gov/earthquakes/eventp...
# 7  https://earthquake.usgs.gov/earthquakes/eventp...
# 8  https://earthquake.usgs.gov/earthquakes/eventp...
# 9  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail  properties.felt  ...  \
# 0  https://earthquake.usgs.gov/earthquakes/feed/v...              1.0  ...
# 1  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 2  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 3  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 4  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 5  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 6  https://earthquake.usgs.gov/earthquakes/feed/v...              7.0  ...
# 7  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 8  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 9  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
#
#                                     properties.types  properties.nst  \
# 0                           ,dyfi,origin,phase-data,            50.0
# 1                                ,origin,phase-data,            14.0
# 2                                ,origin,phase-data,            19.0
# 3                                ,origin,phase-data,             NaN
# 4                  ,nearby-cities,origin,phase-data,             6.0
# 5                                ,origin,phase-data,            52.0
# 6  ,dyfi,focal-mechanism,nearby-cities,origin,pha...           121.0
# 7     ,nearby-cities,origin,phase-data,scitech-link,            38.0
# 8                                ,origin,phase-data,             NaN
# 9                                ,origin,phase-data,            15.0
#
#   properties.dmin properties.rms  properties.gap  properties.magType  \
# 0        0.005343           0.33            71.0                  md
# 1        0.003449           0.11           132.0                  md
# 2        0.006361           0.12            56.0                  ml
# 3             NaN           0.37             NaN                  ml
# 4        0.022360           0.05           177.0                  md
# 5        0.041920           0.11            86.0                  md
# 6        0.040360           0.20            15.0                  ml
# 7        0.186500           0.24            49.0                  ml
# 8             NaN           0.58             NaN                  ml
# 9        1.020000           0.19           160.0                  md
#
#   properties.type                                   properties.title  \
# 0      earthquake                  M 3.6 - 7 km S of Volcano, Hawaii
# 1      earthquake                  M 1.8 - 7 km S of Volcano, Hawaii
# 2      earthquake                M 2.0 - 5 km SSW of Volcano, Hawaii
# 3      earthquake          M 1.6 - 15 km W of Four Mile Road, Alaska
# 4      earthquake          M 1.3 - 7 km SSW of San Juan Bautista, CA
# 5      earthquake                  M 2.8 - 0 km NW of Pāhala, Hawaii
# 6      earthquake                    M 2.3 - 7 km NNE of Fontana, CA
# 7      earthquake              M 1.6 - 16 km NNE of Apple Valley, CA
# 8      earthquake                M 1.0 - 15 km SSW of Badger, Alaska
# 9      earthquake  M 3.4 - 77 km W of The Bottom, Bonaire, Saint ...
#
#   geometry.type                               geometry.coordinates
# 0         Point  [-155.237167358398, 19.3778324127197, -0.20999...
# 1         Point  [-155.244171142578, 19.3743324279785, 0.189999...
# 2         Point         [-155.248168945312, 19.3911666870117, 1.5]
# 3         Point                            [-149.4427, 64.5905, 0]
# 4         Point                             [-121.56, 36.78, 8.79]
# 5         Point  [-155.483169555664, 19.2089996337891, 32.38000...
# 6         Point                   [-117.4226667, 34.1523333, 5.23]
# 7         Point                  [-117.1228333, 34.6363333, -0.94]
# 8         Point                          [-147.642, 64.6693, 11.7]
# 9         Point        [-63.9828333333333, 17.5961666666667, 2.33]
#
# [10 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['type', 'id', 'properties.mag', 'properties.place', 'properties.time',
#        'properties.updated', 'properties.tz', 'properties.url',
#        'properties.detail', 'properties.felt', 'properties.cdi',
#        'properties.mmi', 'properties.alert', 'properties.status',
#        'properties.tsunami', 'properties.sig', 'properties.net',
#        'properties.code', 'properties.ids', 'properties.sources',
#        'properties.types', 'properties.nst', 'properties.dmin',
#        'properties.rms', 'properties.gap', 'properties.magType',
#        'properties.type', 'properties.title', 'geometry.type',
#        'geometry.coordinates'],
#       dtype='object')

# %%
# pick the columns I need
df2 = df[['properties.mag','properties.place','geometry.coordinates']]
df2.head()
# Out:
#    properties.mag                   properties.place  \
# 0            3.63          7 km S of Volcano, Hawaii
# 1            1.83          7 km S of Volcano, Hawaii
# 2            2.02        5 km SSW of Volcano, Hawaii
# 3            1.60  15 km W of Four Mile Road, Alaska
# 4            1.28  7 km SSW of San Juan Bautista, CA
#
#                                 geometry.coordinates
# 0  [-155.237167358398, 19.3778324127197, -0.20999...
# 1  [-155.244171142578, 19.3743324279785, 0.189999...
# 2         [-155.248168945312, 19.3911666870117, 1.5]
# 3                            [-149.4427, 64.5905, 0]
# 4                             [-121.56, 36.78, 8.79]

# %%
# split the geometry.coordinates col into long and lat. First entry in the list is long, the second is lat, 3rd is depth in KM

df2[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist())
df2.head()
# Out:
# <ipython-input-31-07e9b6399bc4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist())
# <ipython-input-31-07e9b6399bc4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist())
#    properties.mag                   properties.place  \
# 0            3.63          7 km S of Volcano, Hawaii
# 1            1.83          7 km S of Volcano, Hawaii
# 2            2.02        5 km SSW of Volcano, Hawaii
# 3            1.60  15 km W of Four Mile Road, Alaska
# 4            1.28  7 km SSW of San Juan Bautista, CA
#
#                                 geometry.coordinates   Latitude   Longitude  \
# 0  [-155.237167358398, 19.3778324127197, -0.20999...  19.377832 -155.237167
# 1  [-155.244171142578, 19.3743324279785, 0.189999...  19.374332 -155.244171
# 2         [-155.248168945312, 19.3911666870117, 1.5]  19.391167 -155.248169
# 3                            [-149.4427, 64.5905, 0]  64.590500 -149.442700
# 4                             [-121.56, 36.78, 8.79]  36.780000 -121.560000
#
#    Depth
# 0  -0.21
# 1   0.19
# 2   1.50
# 3   0.00
# 4   8.79

# %%
# drop the Depth and geometry.coordinates
df2 = df2.drop(['Depth','geometry.coordinates'], axis=1)
df2.head()
# Out:
#    properties.mag                   properties.place   Latitude   Longitude
# 0            3.63          7 km S of Volcano, Hawaii  19.377832 -155.237167
# 1            1.83          7 km S of Volcano, Hawaii  19.374332 -155.244171
# 2            2.02        5 km SSW of Volcano, Hawaii  19.391167 -155.248169
# 3            1.60  15 km W of Four Mile Road, Alaska  64.590500 -149.442700
# 4            1.28  7 km SSW of San Juan Bautista, CA  36.780000 -121.560000

# %%
# rename properties.mag and properties.place
df2 = df2.rename(columns={'properties.mag':'Magnitude','properties.place':'Location'})
df2.head()
# Out:
#    Magnitude                           Location   Latitude   Longitude
# 0       3.63          7 km S of Volcano, Hawaii  19.377832 -155.237167
# 1       1.83          7 km S of Volcano, Hawaii  19.374332 -155.244171
# 2       2.02        5 km SSW of Volcano, Hawaii  19.391167 -155.248169
# 3       1.60  15 km W of Four Mile Road, Alaska  64.590500 -149.442700
# 4       1.28  7 km SSW of San Juan Bautista, CA  36.780000 -121.560000

# %%
# remove the index column
df2 = df2.reset_index(drop=True)
df2.head()
# Out:
#    Magnitude                           Location   Latitude   Longitude
# 0       3.63          7 km S of Volcano, Hawaii  19.377832 -155.237167
# 1       1.83          7 km S of Volcano, Hawaii  19.374332 -155.244171
# 2       2.02        5 km SSW of Volcano, Hawaii  19.391167 -155.248169
# 3       1.60  15 km W of Four Mile Road, Alaska  64.590500 -149.442700
# 4       1.28  7 km SSW of San Juan Bautista, CA  36.780000 -121.560000

# %%
# save the output as csv
df2.to_csv('earthquakes_data.csv', index=False)
