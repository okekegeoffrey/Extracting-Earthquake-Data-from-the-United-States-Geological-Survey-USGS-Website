# %% [markdown]
# In this project, you are expected to use Python to access the United States Geological Survey free API and download real-time earthquake events. This is a great exercise for learning how to use Python to send requests to a REST API and get data in return.
#
# The API endpoint to get earthquake data is as variable "api" below.

# %%
# import the necessary modules
import pandas as pd
import requests

# %%
# the link to the json API
api = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson"

# %%
# import the json into pandas
response = requests.get(api) # fetch the data
data = response.json() # parse the result as  json

# normalise the 'features' list to handle potential inconsistencies
df = pd.json_normalize(data['features'])

df.head(10)
# Out:
#       type          id  properties.mag                   properties.place  \
# 0  Feature  nc75045922            0.27        10 km NW of The Geysers, CA
# 1  Feature  ci40694559            2.18          23 km NW of Grapevine, CA
# 2  Feature  ci40694551            1.95    17 km SSW of Searles Valley, CA
# 3  Feature  nn00882117            1.50            29 km S of Mina, Nevada
# 4  Feature  nc75045907            1.52         2 km NW of The Geysers, CA
# 5  Feature  ok2024pnla            1.41        4 km NNW of Minco, Oklahoma
# 6  Feature  us6000niy6            5.40        7 km WSW of Miyazaki, Japan
# 7  Feature  ci40694511            1.23           3 km E of Villa Park, CA
# 8  Feature  ci40694503            1.29        11 km SW of Salton City, CA
# 9  Feature  nn00882107            0.50  21 km N of Indian Springs, Nevada
#
#    properties.time  properties.updated properties.tz  \
# 0    1723149411220       1723149506677          None
# 1    1723149115920       1723149489959          None
# 2    1723148964460       1723149798964          None
# 3    1723148384523       1723148549970          None
# 4    1723148208860       1723149656610          None
# 5    1723145171880       1723146394653          None
# 6    1723145013073       1723147011436          None
# 7    1723144678860       1723145065502          None
# 8    1723144460750       1723144830636          None
# 9    1723144380386       1723144491091          None
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
# 5  https://earthquake.usgs.gov/earthquakes/eventp...
# 6  https://earthquake.usgs.gov/earthquakes/eventp...
# 7  https://earthquake.usgs.gov/earthquakes/eventp...
# 8  https://earthquake.usgs.gov/earthquakes/eventp...
# 9  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail  properties.felt  ...  \
# 0  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 1  https://earthquake.usgs.gov/earthquakes/feed/v...              1.0  ...
# 2  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 3  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 4  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 5  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 6  https://earthquake.usgs.gov/earthquakes/feed/v...              1.0  ...
# 7  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 8  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
# 9  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN  ...
#
#                                     properties.types  properties.nst  \
# 0                  ,nearby-cities,origin,phase-data,            10.0
# 1  ,dyfi,nearby-cities,origin,phase-data,scitech-...            33.0
# 2  ,focal-mechanism,nearby-cities,origin,phase-da...            30.0
# 3                                ,origin,phase-data,             8.0
# 4     ,nearby-cities,origin,phase-data,scitech-link,            27.0
# 5                                ,origin,phase-data,            78.0
# 6  ,dyfi,losspager,moment-tensor,origin,phase-dat...           104.0
# 7     ,nearby-cities,origin,phase-data,scitech-link,            12.0
# 8     ,nearby-cities,origin,phase-data,scitech-link,            36.0
# 9                                ,origin,phase-data,            13.0
#
#   properties.dmin properties.rms  properties.gap  properties.magType  \
# 0        0.004067         0.0100          102.00                  md
# 1        0.035900         0.2400           52.00                  ml
# 2        0.030560         0.1100           75.00                  ml
# 3        0.093000         0.2151          114.93                  ml
# 4        0.008566         0.0300           79.00                  md
# 5        0.056689         0.4300           42.00                  ml
# 6        5.564000         0.7000           52.00                 mww
# 7        0.015470         0.1400          159.00                  ml
# 8        0.065050         0.1900          106.00                  ml
# 9        0.260000         0.2584          285.48                  ml
#
#   properties.type                           properties.title geometry.type  \
# 0      earthquake        M 0.3 - 10 km NW of The Geysers, CA         Point
# 1      earthquake          M 2.2 - 23 km NW of Grapevine, CA         Point
# 2      earthquake    M 2.0 - 17 km SSW of Searles Valley, CA         Point
# 3      earthquake            M 1.5 - 29 km S of Mina, Nevada         Point
# 4      earthquake         M 1.5 - 2 km NW of The Geysers, CA         Point
# 5      earthquake        M 1.4 - 4 km NNW of Minco, Oklahoma         Point
# 6      earthquake        M 5.4 - 7 km WSW of Miyazaki, Japan         Point
# 7      earthquake           M 1.2 - 3 km E of Villa Park, CA         Point
# 8      earthquake        M 1.3 - 11 km SW of Salton City, CA         Point
# 9      earthquake  M 0.5 - 21 km N of Indian Springs, Nevada         Point
#
#                 geometry.coordinates
# 0             [-122.85, 38.83, 1.97]
# 1  [-119.1206665, 35.0779991, 13.68]
# 2           [-117.447, 35.6145, 6.3]
# 3           [-118.0598, 38.127, 1.5]
# 4             [-122.78, 38.79, 1.71]
# 5  [-97.96516667, 35.35033333, 6.75]
# 6         [131.341, 31.8881, 19.497]
# 7        [-117.7781667, 33.816, 7.1]
# 8   [-116.0291667, 33.2223333, 6.22]
# 9          [-115.6637, 36.7632, 2.9]
#
# [10 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['type', 'id', 'properties.mag', 'properties.place', 'properties.time',
#        'properties.updated', 'properties.tz', 'properties.url',
#        'properties.detail', 'properties.felt', 'properties.cdi',
#        'properties.mmi', 'properties.alert', 'properties.status',
#        'properties.tsunami', 'properties.sig', 'properties.net',
#        'properties.code', 'properties.ids', 'properties.sources',
#        'properties.types', 'properties.nst', 'properties.dmin',
#        'properties.rms', 'properties.gap', 'properties.magType',
#        'properties.type', 'properties.title', 'geometry.type',
#        'geometry.coordinates'],
#       dtype='object')

# %%
# pick the columns I need
df2 = df[['properties.mag','properties.place','geometry.coordinates']]
df2.head()
# Out:
#    properties.mag                 properties.place  \
# 0            0.27      10 km NW of The Geysers, CA
# 1            2.18        23 km NW of Grapevine, CA
# 2            1.95  17 km SSW of Searles Valley, CA
# 3            1.50          29 km S of Mina, Nevada
# 4            1.52       2 km NW of The Geysers, CA
#
#                 geometry.coordinates
# 0             [-122.85, 38.83, 1.97]
# 1  [-119.1206665, 35.0779991, 13.68]
# 2           [-117.447, 35.6145, 6.3]
# 3           [-118.0598, 38.127, 1.5]
# 4             [-122.78, 38.79, 1.71]

# %%
# split the geometry.coordinates col into long and lat. First entry in the list is long, the second is lat, 3rd is depth in KM

df2[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist())
df2.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28240\3659130908.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist())
# C:\Users\user\AppData\Local\Temp\ipykernel_28240\3659130908.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist())
# C:\Users\user\AppData\Local\Temp\ipykernel_28240\3659130908.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist())
#    properties.mag                 properties.place  \
# 0            0.27      10 km NW of The Geysers, CA
# 1            2.18        23 km NW of Grapevine, CA
# 2            1.95  17 km SSW of Searles Valley, CA
# 3            1.50          29 km S of Mina, Nevada
# 4            1.52       2 km NW of The Geysers, CA
#
#                 geometry.coordinates   Longitude   Latitude  Depth
# 0             [-122.85, 38.83, 1.97] -122.850000  38.830000   1.97
# 1  [-119.1206665, 35.0779991, 13.68] -119.120666  35.077999  13.68
# 2           [-117.447, 35.6145, 6.3] -117.447000  35.614500   6.30
# 3           [-118.0598, 38.127, 1.5] -118.059800  38.127000   1.50
# 4             [-122.78, 38.79, 1.71] -122.780000  38.790000   1.71

# %%
# drop the Depth and geometry.coordinates
df2 = df2.drop(['Depth','geometry.coordinates'], axis=1)
df2.head()
# Out:
#    properties.mag                 properties.place   Longitude   Latitude
# 0            0.27      10 km NW of The Geysers, CA -122.850000  38.830000
# 1            2.18        23 km NW of Grapevine, CA -119.120666  35.077999
# 2            1.95  17 km SSW of Searles Valley, CA -117.447000  35.614500
# 3            1.50          29 km S of Mina, Nevada -118.059800  38.127000
# 4            1.52       2 km NW of The Geysers, CA -122.780000  38.790000

# %%
# rename properties.mag and properties.place
df2 = df2.rename(columns={'properties.mag':'Magnitude','properties.place':'Location'})
df2.head()
# Out:
#    Magnitude                         Location   Longitude   Latitude
# 0       0.27      10 km NW of The Geysers, CA -122.850000  38.830000
# 1       2.18        23 km NW of Grapevine, CA -119.120666  35.077999
# 2       1.95  17 km SSW of Searles Valley, CA -117.447000  35.614500
# 3       1.50          29 km S of Mina, Nevada -118.059800  38.127000
# 4       1.52       2 km NW of The Geysers, CA -122.780000  38.790000

# %%
# remove the index column
df2 = df2.reset_index(drop=True)
df2.head()
# Out:
#    Magnitude                         Location   Longitude   Latitude
# 0       0.27      10 km NW of The Geysers, CA -122.850000  38.830000
# 1       2.18        23 km NW of Grapevine, CA -119.120666  35.077999
# 2       1.95  17 km SSW of Searles Valley, CA -117.447000  35.614500
# 3       1.50          29 km S of Mina, Nevada -118.059800  38.127000
# 4       1.52       2 km NW of The Geysers, CA -122.780000  38.790000

# %%
# save the output as csv
df2.to_csv('earthquakes_data.csv', index=False)
